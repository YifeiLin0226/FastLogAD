# %%
from train_test.tester import ElectraTester
import yaml
import os
# Out:
# /home/yifei/LogAnomaly/venv/lib/python3.8/site-packages/torch/cuda/__init__.py:611: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
configs = yaml.load(open(os.path.join('./configs', 'bgl.yaml'), 'r'), Loader=yaml.FullLoader)
model_configs = configs['model_configs']

# %%
tester = ElectraTester(model_configs, configs)
fig = tester.test()
# Out:
# Using device cuda
# Loading Vocab...
# VOCAB SIZE: 185
# Loading Vocab Done!
# IN MODEL: RANDOM GENERATOR: False
# Testing...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 396/396 [00:09<00:00, 42.40it/s]
# plot displot...
# AUROC: 0.9933
# AUPR: 0.9848
# ROC threshold: 0.051193
# Accuracy: 0.9782
# Precision: 0.9185
# Recall: 0.9774
# F1: 0.9470
# PR threshold: 0.082673
# Accuracy: 0.9808
# Precision: 0.9521
# Recall: 0.9517
# F1: 0.9519
# Threshold: 0.155085
# Accuracy: 0.9818
# Precision: 0.9625
# Recall: 0.9453
# F1: 0.9538
